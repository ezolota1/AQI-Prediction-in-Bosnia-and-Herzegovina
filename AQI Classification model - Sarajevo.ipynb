# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data = pd.read_csv('C:/Pythondatasets/All_Valid_Datasets_Sarajevo_sa_datumom - Copy.csv')
data
# Out:
#             date      Site          Parameter        Date (LT)  Hour  \
# 0      5/22/2018  Sarajevo  PM2.5 - Principal  5/22/2018 17:00    17
# 1      5/22/2018  Sarajevo  PM2.5 - Principal  5/22/2018 18:00    18
# 2      5/22/2018  Sarajevo  PM2.5 - Principal  5/22/2018 19:00    19
# 3      5/22/2018  Sarajevo  PM2.5 - Principal  5/22/2018 20:00    20
# 4      5/22/2018  Sarajevo  PM2.5 - Principal  5/22/2018 21:00    21
# ...          ...       ...                ...              ...   ...
# 45178  4/30/2023  Sarajevo  PM2.5 - Principal  4/30/2023 21:00    21
# 45179  4/30/2023  Sarajevo  PM2.5 - Principal  4/30/2023 22:00    22
# 45180  4/30/2023  Sarajevo  PM2.5 - Principal  4/30/2023 23:00    23
# 45181   5/1/2023  Sarajevo  PM2.5 - Principal    5/1/2023 0:00     0
# 45182   5/1/2023  Sarajevo  PM2.5 - Principal    5/1/2023 1:00     1
#
#        NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration QC Name  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
X=data[['Year', 'Month', 'Hour', 'Raw Conc.', 'NowCast Conc.']]
Y=data['AQI Category']

#setup1 za predviđanje
X=data[['diskretno_vrijeme']] 
Y=data['AQI']

X=data[['diskretno_vrijeme']]
Y=data['PM2.5']
# obicna regresija, feed forward mrezu, 1 ulaz - 2 izlaza, neku deep mrezu

#setup2 za predviđanje
X=data[['diskretno_vrijeme', 'Hour']] 
Y=data['AQI']
# obicna regresija, feed forward mrezu, 1 ulaz - 2 izlaza, neku deep mrezu

X=data[['diskretno_vrijeme', 'Hour']]
Y=data['PM2.5']

#setup3 za predviđanje
X=data[['diskretno_vrijeme', 'Hour', 'Month']] 
Y=data['AQI']
# obicna regresija, feed forward mrezu, 1 ulaz - 2 izlaza, neku deep mrezu

X=data[['diskretno_vrijeme', 'Hour', 'Month']]
Y=data['PM2.5']

#setup4 za predviđanje

X=data[['diskretno_vrijeme', 'Hour', 'Month', 'diskretno_vrijeme-1', 'AQI[diskretno_vrijeme-1]', 'diskretno_vrijeme -2', 'AQI[diskretno_vrijeme-2]', 'diskretno_vrijeme -3', 'AQI[diskretno_vrijeme-3]']] 
Y=data['AQI'], 
# obicna regresija, feed forward mrezu, 1 ulaz - 2 izlaza, neku deep mrezu

X=data[['diskretno_vrijeme', 'Hour']]
Y=data['PM2.5']

#setup5 za predviđanje
#uzimanje 7 vrijednosti iz historije koje odgovaraju istom satu posljednjih sedam dana da bi se predvijela vrijednost dana poslije
#arimo model, autoregresivne neuronske mreze, logisticku regresiju, decision trees, sarima model

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X, Y, test_size=0.33, random_state=70)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (30272, 5) (14911, 5) (30272,) (14911,)

# %%
# Logistic Regression

log_reg=LogisticRegression().fit(X_train, Y_train)

train_pred=log_reg.predict(X_train)
print("Model accuracy on train is: ", accuracy_score(Y_train, train_pred))

test_pred=log_reg.predict(X_test)
print("Model accuracy on test is: ", accuracy_score(Y_test, test_pred))
print("-"*50)

print("KappaScore is ", metrics.cohen_kappa_score(Y_test, test_pred))
# Out:
# Model accuracy on train is:  0.9317851479915433
# Model accuracy on test is:  0.9336731272215143
# --------------------------------------------------
# KappaScore is  0.9047809601578292

# %%
log_reg.predict([[2025, 1, 10, 13.0, 10.0]])
# Out:
# array(['Good'], dtype=object)

# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2018_YTD.csv')
df2 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2019_12_MTD.csv')
df3 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2019_YTD.csv')
df4 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2020_12_MTD.csv')
df5 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2020_YTD.csv')
df6 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2021_12_MTD.csv')
df7 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2021_YTD.csv')
df8 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2022_12_MTD.csv')
df9 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2022_YTD.csv')
df10 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2023_05_MTD.csv')
df11 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2023_12_MTD.csv')
df12 = pd.read_csv('C:/Pythondatasets/Sarajevo_PM2.5_2023_YTD.csv')

# %%
df1.shape
# Out:
# (5378, 14)

# %%
df12
# Out:
#           Site          Parameter            Date (LT)  Year  Month  Day  \
# 0     Sarajevo  PM2.5 - Principal  2023-01-01 01:00 AM  2023      1    1
# 1     Sarajevo  PM2.5 - Principal  2023-01-01 02:00 AM  2023      1    1
# 2     Sarajevo  PM2.5 - Principal  2023-01-01 03:00 AM  2023      1    1
# 3     Sarajevo  PM2.5 - Principal  2023-01-01 04:00 AM  2023      1    1
# 4     Sarajevo  PM2.5 - Principal  2023-01-01 05:00 AM  2023      1    1
# ...        ...                ...                  ...   ...    ...  ...
# 2872  Sarajevo  PM2.5 - Principal  2023-04-30 09:00 PM  2023      4   30
# 2873  Sarajevo  PM2.5 - Principal  2023-04-30 10:00 PM  2023      4   30
# 2874  Sarajevo  PM2.5 - Principal  2023-04-30 11:00 PM  2023      4   30
# 2875  Sarajevo  PM2.5 - Principal  2023-05-01 12:00 AM  2023      5    1
# 2876  Sarajevo  PM2.5 - Principal  2023-05-01 01:00 AM  2023      5    1
#
#       Hour  NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration  \
# ...

# %%
all_df = [ df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12 ]

# %%
data = pd.concat(all_df)

# %%
data
# Out:
#           Site          Parameter            Date (LT)  Year  Month  Day  \
# 0     Sarajevo  PM2.5 - Principal  2018-03-22 02:00 PM  2018      3   22
# 1     Sarajevo  PM2.5 - Principal  2018-03-22 03:00 PM  2018      3   22
# 2     Sarajevo  PM2.5 - Principal  2018-03-22 04:00 PM  2018      3   22
# 3     Sarajevo  PM2.5 - Principal  2018-05-15 12:00 PM  2018      5   15
# 4     Sarajevo  PM2.5 - Principal  2018-05-15 01:00 PM  2018      5   15
# ...        ...                ...                  ...   ...    ...  ...
# 2872  Sarajevo  PM2.5 - Principal  2023-04-30 09:00 PM  2023      4   30
# 2873  Sarajevo  PM2.5 - Principal  2023-04-30 10:00 PM  2023      4   30
# 2874  Sarajevo  PM2.5 - Principal  2023-04-30 11:00 PM  2023      4   30
# 2875  Sarajevo  PM2.5 - Principal  2023-05-01 12:00 AM  2023      5    1
# 2876  Sarajevo  PM2.5 - Principal  2023-05-01 01:00 AM  2023      5    1
#
#       Hour  NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration  \
# ...

# %%
data.to_csv('C:/Pythondatasets/All_datasets_Sarajevo.csv', index=False)

# %%
data = data.loc[(data["QC Name"] == 'Valid') & (data["AQI"] > 0)]

# %%
data
# Out:
#           Site          Parameter            Date (LT)  Year  Month  Day  \
# 46    Sarajevo  PM2.5 - Principal  2018-05-22 05:00 PM  2018      5   22
# 47    Sarajevo  PM2.5 - Principal  2018-05-22 06:00 PM  2018      5   22
# 48    Sarajevo  PM2.5 - Principal  2018-05-22 07:00 PM  2018      5   22
# 49    Sarajevo  PM2.5 - Principal  2018-05-22 08:00 PM  2018      5   22
# 50    Sarajevo  PM2.5 - Principal  2018-05-22 09:00 PM  2018      5   22
# ...        ...                ...                  ...   ...    ...  ...
# 2872  Sarajevo  PM2.5 - Principal  2023-04-30 09:00 PM  2023      4   30
# 2873  Sarajevo  PM2.5 - Principal  2023-04-30 10:00 PM  2023      4   30
# 2874  Sarajevo  PM2.5 - Principal  2023-04-30 11:00 PM  2023      4   30
# 2875  Sarajevo  PM2.5 - Principal  2023-05-01 12:00 AM  2023      5    1
# 2876  Sarajevo  PM2.5 - Principal  2023-05-01 01:00 AM  2023      5    1
#
#       Hour  NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration  \
# ...

# %%
data.to_csv('C:/Pythondatasets/All_Valid_Datasets_Sarajevo_vol2.csv', index=False)

# %%
import numpy as np

# %%
data = data.loc[data["Year"] == 2022]
data
# Out:
#           Site          Parameter            Date (LT)  Year  Month  Day  \
# 8709  Sarajevo  PM2.5 - Principal  2022-01-01 12:00 AM  2022      1    1
# 743   Sarajevo  PM2.5 - Principal  2022-01-01 12:00 AM  2022      1    1
# 0     Sarajevo  PM2.5 - Principal  2022-01-01 01:00 AM  2022      1    1
# 1     Sarajevo  PM2.5 - Principal  2022-01-01 02:00 AM  2022      1    1
# 2     Sarajevo  PM2.5 - Principal  2022-01-01 03:00 AM  2022      1    1
# ...        ...                ...                  ...   ...    ...  ...
# 738   Sarajevo  PM2.5 - Principal  2022-12-31 07:00 PM  2022     12   31
# 739   Sarajevo  PM2.5 - Principal  2022-12-31 08:00 PM  2022     12   31
# 740   Sarajevo  PM2.5 - Principal  2022-12-31 09:00 PM  2022     12   31
# 741   Sarajevo  PM2.5 - Principal  2022-12-31 10:00 PM  2022     12   31
# 742   Sarajevo  PM2.5 - Principal  2022-12-31 11:00 PM  2022     12   31
#
#       Hour  NowCast Conc.  AQI    AQI Category  Raw Conc. Conc. Unit Duration  \
# ...

# %%
table2022=pd.pivot_table(data, index=['Month'], values=['Raw Conc.'], aggfunc=[np.mean, min, max, np.std])
table2022
# Out:
#             mean       min       max        std
#        Raw Conc. Raw Conc. Raw Conc.  Raw Conc.
# Month
# 1      97.691375       1.0     366.0  83.480968
# 2      41.026946       3.0     257.0  37.572349
# 3      31.894309       1.0      95.0  15.031300
# 4      15.190808       0.0      58.0  10.094592
# 5      15.548518       2.0      56.0   5.770902
# 6      16.452646       3.0     135.0   8.053507
# 7      15.830163       1.0     202.0  10.521618
# 8      15.012179       2.0      43.0   6.139623
# 9      13.483405      -1.0      45.0   7.402649
# 10     30.970350       3.0      89.0  14.805320
# 11     50.397143      -1.0     187.0  37.466773
# 12     75.716790       1.0     298.0  62.013315

# %%
print(table2022.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &       mean &       min &       max &        std \\
# {} &  Raw Conc. & Raw Conc. & Raw Conc. &  Raw Conc. \\
# Month &            &           &           &            \\
# \midrule
# 1     &  97.691375 &       1.0 &     366.0 &  83.480968 \\
# 2     &  41.026946 &       3.0 &     257.0 &  37.572349 \\
# 3     &  31.894309 &       1.0 &      95.0 &  15.031300 \\
# 4     &  15.190808 &       0.0 &      58.0 &  10.094592 \\
# 5     &  15.548518 &       2.0 &      56.0 &   5.770902 \\
# 6     &  16.452646 &       3.0 &     135.0 &   8.053507 \\
# 7     &  15.830163 &       1.0 &     202.0 &  10.521618 \\
# 8     &  15.012179 &       2.0 &      43.0 &   6.139623 \\
# 9     &  13.483405 &      -1.0 &      45.0 &   7.402649 \\
# 10    &  30.970350 &       3.0 &      89.0 &  14.805320 \\
# 11    &  50.397143 &      -1.0 &     187.0 &  37.466773 \\
# 12    &  75.716790 &       1.0 &     298.0 &  62.013315 \\
# \bottomrule
# \end{tabular}
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
AQIPoGodinama=data.groupby('Year')['AQI'].max()
AQIPoGodinamaX=AQIPoGodinama.index.tolist()
AQIPoGodinamaY=AQIPoGodinama.values.tolist()
AQIPoGodinama
# Out:
# Year
# 2018    526
# 2019    427
# 2020    572
# 2021    317
# 2022    395
# 2023    383
# Name: AQI, dtype: int64

# %%
plt.title("Maksimalna AQI vrijednost tokom godina")
plt.xlabel("Godina")
plt.ylabel("AQI")
addlabels(AQIPoGodinamaX, AQIPoGodinamaY)

AQIPoGodinama.plot(kind="bar", color="red")
# Out:
# <AxesSubplot:title={'center':'Maksimalna AQI vrijednost tokom godina'}, xlabel='Year', ylabel='AQI'>

# %%
januari=data.loc[data['Month']==1]

# %%
januari
# Out:
#           Site          Parameter            Date (LT)  Year  Month  Day  \
# 5377  Sarajevo  PM2.5 - Principal  2019-01-01 12:00 AM  2019      1    1
# 743   Sarajevo  PM2.5 - Principal  2019-01-01 12:00 AM  2019      1    1
# 0     Sarajevo  PM2.5 - Principal  2019-01-01 01:00 AM  2019      1    1
# 1     Sarajevo  PM2.5 - Principal  2019-01-01 02:00 AM  2019      1    1
# 2     Sarajevo  PM2.5 - Principal  2019-01-01 03:00 AM  2019      1    1
# ...        ...                ...                  ...   ...    ...  ...
# 737   Sarajevo  PM2.5 - Principal  2023-01-31 07:00 PM  2023      1   31
# 738   Sarajevo  PM2.5 - Principal  2023-01-31 08:00 PM  2023      1   31
# 739   Sarajevo  PM2.5 - Principal  2023-01-31 09:00 PM  2023      1   31
# 740   Sarajevo  PM2.5 - Principal  2023-01-31 10:00 PM  2023      1   31
# 741   Sarajevo  PM2.5 - Principal  2023-01-31 11:00 PM  2023      1   31
#
#       Hour  NowCast Conc.  AQI                    AQI Category  Raw Conc.  \
# ...

# %%
januariPoGodinama=januari.groupby('Year')['AQI'].max()
januariPoGodinama
# Out:
# Year
# 2019    415
# 2020    572
# 2021    317
# 2022    395
# 2023    383
# Name: AQI, dtype: int64

# %%
def addlabels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i], round(y[i], 1), ha='center')

# %%
plt.title("Maksimalna AQI vrijednost u januaru tokom godina")
plt.xlabel("Godina")
plt.ylabel("AQI")
x=januariPoGodinama.index.tolist()
y=januariPoGodinama.values.tolist()
addlabels(x, y)

januariPoGodinama.plot(kind="bar", color="red")
plt.savefig('C:/Pythondatasets/maks_vrijednost_AQI_januar_po_godinama.png')

# %%
januari
# Out:
#           Site          Parameter            Date (LT)  Year  Month  Day  \
# 5377  Sarajevo  PM2.5 - Principal  2019-01-01 12:00 AM  2019      1    1
# 743   Sarajevo  PM2.5 - Principal  2019-01-01 12:00 AM  2019      1    1
# 0     Sarajevo  PM2.5 - Principal  2019-01-01 01:00 AM  2019      1    1
# 1     Sarajevo  PM2.5 - Principal  2019-01-01 02:00 AM  2019      1    1
# 2     Sarajevo  PM2.5 - Principal  2019-01-01 03:00 AM  2019      1    1
# ...        ...                ...                  ...   ...    ...  ...
# 737   Sarajevo  PM2.5 - Principal  2023-01-31 07:00 PM  2023      1   31
# 738   Sarajevo  PM2.5 - Principal  2023-01-31 08:00 PM  2023      1   31
# 739   Sarajevo  PM2.5 - Principal  2023-01-31 09:00 PM  2023      1   31
# 740   Sarajevo  PM2.5 - Principal  2023-01-31 10:00 PM  2023      1   31
# 741   Sarajevo  PM2.5 - Principal  2023-01-31 11:00 PM  2023      1   31
#
#       Hour  NowCast Conc.  AQI                    AQI Category  Raw Conc.  \
# ...

# %%
januariPoGodinamaSve=januari.groupby('Year')['AQI']
januariPoGodinamaSve

# %%
februari=data.loc[data['Month']==2]
februari
februariPoGodinama=februari.groupby('Year')['AQI'].max()
februariPoGodinama
# Out:
# Year
# 2019    231
# 2020    305
# 2021    234
# 2022    287
# 2023    274
# Name: AQI, dtype: int64

# %%
plt.title("Maksimalna AQI vrijednost u februaru tokom godina")
plt.xlabel("Godina")
plt.ylabel("AQI")
x=februariPoGodinama.index.tolist()
y=februariPoGodinama.values.tolist()
addlabels(x, y)
februariPoGodinama.plot(kind="bar", color="red")
plt.savefig('C:/Pythondatasets/maks_vrijednost_AQI_februar_po_godinama.png')

# %%
decembri=data.loc[data['Month']==12]
decembri
decembriPoGodinama=decembri.groupby('Year')['AQI'].max()
decembriPoGodinama
# Out:
# Year
# 2018    526
# 2019    427
# 2020    411
# 2021    267
# 2022    324
# Name: AQI, dtype: int64

# %%
plt.title("Maksimalna AQI vrijednost u decembru tokom godina")
plt.xlabel("Godina")
plt.ylabel("AQI")
x=decembriPoGodinama.index.tolist()
y=decembriPoGodinama.values.tolist()
addlabels(x, y)
decembriPoGodinama.plot(kind="bar", color="red")
plt.savefig('C:/Pythondatasets/maks_vrijednost_AQI_decembar_po_godinama.png')

# %%
decembriPoGodinamaSrednja=decembri.groupby('Year')['AQI'].mean()
decembriPoGodinamaSrednja
# Out:
# Year
# 2018    190.970330
# 2019    130.664416
# 2020    138.423935
# 2021    113.858879
# 2022    139.527310
# Name: AQI, dtype: float64

# %%
plt.title("Srednja AQI vrijednost u decembru tokom godina")
plt.xlabel("Godina")
plt.ylabel("AQI")
x=decembriPoGodinamaSrednja.index.tolist()
y=decembriPoGodinamaSrednja.values.tolist()
addlabels(x, y)
decembriPoGodinamaSrednja.plot(kind="bar")
plt.savefig('C:/Pythondatasets/avg_vrijednost_AQI_decembar_po_godinama.png')

# %%
c

# %%
februariPoGodinamaSrednja=februari.groupby('Year')['AQI'].mean()
plt.title("Srednja AQI vrijednost u februaru tokom godina")
plt.xlabel("Godina")
plt.ylabel("AQI")
x=februariPoGodinamaSrednja.index.tolist()
y=februariPoGodinamaSrednja.values.tolist()
februariPoGodinamaSrednja.plot(kind="line")
decembriPoGodinamaSrednja.plot(kind="line")
# Out:
# <AxesSubplot:title={'center':'Srednja AQI vrijednost u februaru tokom godina'}, xlabel='Year', ylabel='AQI'>

# %%
plt.title("Maks AQI tokom decembra, januara i februara od 2018. do 2023. godine")
plt.xlabel("Godina")
plt.ylabel("AQI")
januariPoGodinama.plot(label="Januar")
februariPoGodinama.plot(label="Februar")
decembriPoGodinama.plot(label="Decembar")
plt.xlabel("Godina")
plt.legend()
plt.savefig('C:/Pythondatasets/maks_vrijednost_mjeseca_AQI_po_godinama.png')

# %%
decembri
# Out:
#           Site          Parameter            Date (LT)  Year  Month  Day  \
# 4633  Sarajevo  PM2.5 - Principal  2018-12-01 12:00 AM  2018     12    1
# 4634  Sarajevo  PM2.5 - Principal  2018-12-01 01:00 AM  2018     12    1
# 4635  Sarajevo  PM2.5 - Principal  2018-12-01 02:00 AM  2018     12    1
# 4636  Sarajevo  PM2.5 - Principal  2018-12-01 03:00 AM  2018     12    1
# 4637  Sarajevo  PM2.5 - Principal  2018-12-01 04:00 AM  2018     12    1
# ...        ...                ...                  ...   ...    ...  ...
# 738   Sarajevo  PM2.5 - Principal  2022-12-31 07:00 PM  2022     12   31
# 739   Sarajevo  PM2.5 - Principal  2022-12-31 08:00 PM  2022     12   31
# 740   Sarajevo  PM2.5 - Principal  2022-12-31 09:00 PM  2022     12   31
# 741   Sarajevo  PM2.5 - Principal  2022-12-31 10:00 PM  2022     12   31
# 742   Sarajevo  PM2.5 - Principal  2022-12-31 11:00 PM  2022     12   31
#
#       Hour  NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration  \
# ...

# %%
decembri.plot(kind="line", x="Year", y="AQI")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
zagadjenjeSaDatumom = pd.read_csv('C:/Pythondatasets/All_Valid_Datasets_Sarajevo_vol2.csv',
                 parse_dates= {"date" : ["Year","Month","Day"]})
zagadjenjeSaDatumom
# Out:
#             date      Site          Parameter            Date (LT)  Hour  \
# 0     2018-05-22  Sarajevo  PM2.5 - Principal  2018-05-22 05:00 PM    17
# 1     2018-05-22  Sarajevo  PM2.5 - Principal  2018-05-22 06:00 PM    18
# 2     2018-05-22  Sarajevo  PM2.5 - Principal  2018-05-22 07:00 PM    19
# 3     2018-05-22  Sarajevo  PM2.5 - Principal  2018-05-22 08:00 PM    20
# 4     2018-05-22  Sarajevo  PM2.5 - Principal  2018-05-22 09:00 PM    21
# ...          ...       ...                ...                  ...   ...
# 45178 2023-04-30  Sarajevo  PM2.5 - Principal  2023-04-30 09:00 PM    21
# 45179 2023-04-30  Sarajevo  PM2.5 - Principal  2023-04-30 10:00 PM    22
# 45180 2023-04-30  Sarajevo  PM2.5 - Principal  2023-04-30 11:00 PM    23
# 45181 2023-05-01  Sarajevo  PM2.5 - Principal  2023-05-01 12:00 AM     0
# 45182 2023-05-01  Sarajevo  PM2.5 - Principal  2023-05-01 01:00 AM     1
#
#        NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration QC Name
# ...

# %%
zagadjenjeSaDatumom.to_csv('C:/Pythondatasets/All_Valid_Datasets_Sarajevo_sa_datumom.csv', index=False)

# %%
data
# Out:
#           Site          Parameter            Date (LT)  Year  Month  Day  \
# 46    Sarajevo  PM2.5 - Principal  2018-05-22 05:00 PM  2018      5   22
# 47    Sarajevo  PM2.5 - Principal  2018-05-22 06:00 PM  2018      5   22
# 48    Sarajevo  PM2.5 - Principal  2018-05-22 07:00 PM  2018      5   22
# 49    Sarajevo  PM2.5 - Principal  2018-05-22 08:00 PM  2018      5   22
# 50    Sarajevo  PM2.5 - Principal  2018-05-22 09:00 PM  2018      5   22
# ...        ...                ...                  ...   ...    ...  ...
# 2872  Sarajevo  PM2.5 - Principal  2023-04-30 09:00 PM  2023      4   30
# 2873  Sarajevo  PM2.5 - Principal  2023-04-30 10:00 PM  2023      4   30
# 2874  Sarajevo  PM2.5 - Principal  2023-04-30 11:00 PM  2023      4   30
# 2875  Sarajevo  PM2.5 - Principal  2023-05-01 12:00 AM  2023      5    1
# 2876  Sarajevo  PM2.5 - Principal  2023-05-01 01:00 AM  2023      5    1
#
#       Hour  NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration  \
# ...

# %%
plt.title("AQI vrijednost tokom godina")
plt.xlabel("Godina")
plt.ylabel("AQI")
x=zagadjenjeSaDatumom['date']
y=zagadjenjeSaDatumom['AQI']
addlabels(x, y)
plt.plot(x, y)

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23848\391604064.py in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
def addlabels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i], round(y[i], 1), ha='center')

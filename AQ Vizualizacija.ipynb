# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('C:/Pythondatasets/All_Valid_Datasets_Sarajevo_vol2.csv')

# %%
data
# Out:
#            Site          Parameter            Date (LT)  Year  Month  Day  \
# 0      Sarajevo  PM2.5 - Principal  2018-05-22 05:00 PM  2018      5   22
# 1      Sarajevo  PM2.5 - Principal  2018-05-22 06:00 PM  2018      5   22
# 2      Sarajevo  PM2.5 - Principal  2018-05-22 07:00 PM  2018      5   22
# 3      Sarajevo  PM2.5 - Principal  2018-05-22 08:00 PM  2018      5   22
# 4      Sarajevo  PM2.5 - Principal  2018-05-22 09:00 PM  2018      5   22
# ...         ...                ...                  ...   ...    ...  ...
# 45178  Sarajevo  PM2.5 - Principal  2023-04-30 09:00 PM  2023      4   30
# 45179  Sarajevo  PM2.5 - Principal  2023-04-30 10:00 PM  2023      4   30
# 45180  Sarajevo  PM2.5 - Principal  2023-04-30 11:00 PM  2023      4   30
# 45181  Sarajevo  PM2.5 - Principal  2023-05-01 12:00 AM  2023      5    1
# 45182  Sarajevo  PM2.5 - Principal  2023-05-01 01:00 AM  2023      5    1
#
#        Hour  NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration  \
# ...

# %%
plt.title("AQI vrijednost tokom godina")
plt.xlabel("Godina")
plt.ylabel("AQI")
x=data['date']
y=data['AQI']
plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
zagadjenjeSaDatumom = pd.read_csv('C:/Pythondatasets/All_Valid_Datasets_Sarajevo_vol2.csv',
                 parse_dates= {"date" : ["Year","Month","Day"]})
data=zagadjenjeSaDatumom

# %%
zagadjenjeSaDatumomBL = pd.read_csv('C:/Pythondatasets/Banja Luka/All_Valid_Datasets_BanjaLuka_without_duplicates.csv',
                 parse_dates= {"date" : ["Year","Month","Day"]})
zagadjenjeSaDatumomBL
# Out:
#             date        Site          Parameter            Date (LT)  Hour  \
# 0     2021-09-08  Banja Luka  PM2.5 - Principal  2021-09-08 08:00 PM    20
# 1     2021-09-08  Banja Luka  PM2.5 - Principal  2021-09-08 09:00 PM    21
# 2     2021-09-08  Banja Luka  PM2.5 - Principal  2021-09-08 10:00 PM    22
# 3     2021-09-08  Banja Luka  PM2.5 - Principal  2021-09-08 11:00 PM    23
# 4     2021-09-09  Banja Luka  PM2.5 - Principal  2021-09-09 12:00 AM     0
# ...          ...         ...                ...                  ...   ...
# 14016 2023-05-31  Banja Luka  PM2.5 - Principal  2023-05-31 09:00 PM    21
# 14017 2023-05-31  Banja Luka  PM2.5 - Principal  2023-05-31 10:00 PM    22
# 14018 2023-05-31  Banja Luka  PM2.5 - Principal  2023-05-31 11:00 PM    23
# 14019 2023-06-01  Banja Luka  PM2.5 - Principal  2023-06-01 12:00 AM     0
# 14020 2023-06-01  Banja Luka  PM2.5 - Principal  2023-06-01 01:00 AM     1
#
# ...

# %%
plt.title("AQI in Sarajevo")
plt.xlabel("Year")
plt.ylabel("AQI")
x=zagadjenjeSaDatumom['date']
y=zagadjenjeSaDatumom['AQI']
plt.plot(x, y)
plt.savefig('C:/Pythondatasets/AQI_Sarajevo.png')

# %%
plt.title("AQI in Banja Luka")
plt.xlabel("Year")
plt.ylabel("AQI")

x=zagadjenjeSaDatumomBL['date']
y=zagadjenjeSaDatumomBL['AQI']
ticks_data = [2021,2022,2023]
plt.xticks([2021,2022,2023])

plt.plot(x, y)

plt.savefig('C:/Pythondatasets/AQI_BanjaLuka.png')

# %%
februari=data.loc[data['Month']==2]
februari
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
februariPoGodinama=februari.groupby(['Year', 'date'])['AQI'].max()
februariPoGodinama
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3976\2682303291.py in <module>
# ----> 1 februariPoGodinama=februari.groupby(['Year', 'date'])['AQI'].max()
#       2 februariPoGodinama
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7719         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720         # "Union[bool, NoDefault]"; expected "bool"
# -> 7721         return DataFrameGroupBy(
#    7722             obj=self,
#    7723             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
januari=data.loc[data['Month']==1]
januari
# Out:
#             date      Site          Parameter        Date (LT)  Hour  \
# 5295    1/1/2019  Sarajevo  PM2.5 - Principal    1/1/2019 0:00     0
# 6037    1/1/2019  Sarajevo  PM2.5 - Principal    1/1/2019 0:00     0
# 6038    1/1/2019  Sarajevo  PM2.5 - Principal    1/1/2019 1:00     1
# 6039    1/1/2019  Sarajevo  PM2.5 - Principal    1/1/2019 2:00     2
# 6040    1/1/2019  Sarajevo  PM2.5 - Principal    1/1/2019 3:00     3
# ...          ...       ...                ...              ...   ...
# 43067  1/31/2023  Sarajevo  PM2.5 - Principal  1/31/2023 19:00    19
# 43068  1/31/2023  Sarajevo  PM2.5 - Principal  1/31/2023 20:00    20
# 43069  1/31/2023  Sarajevo  PM2.5 - Principal  1/31/2023 21:00    21
# 43070  1/31/2023  Sarajevo  PM2.5 - Principal  1/31/2023 22:00    22
# 43071  1/31/2023  Sarajevo  PM2.5 - Principal  1/31/2023 23:00    23
#
#        NowCast Conc.  AQI                    AQI Category  Raw Conc.  \
# ...

# %%
januariPoGodinama=januari.groupby(['Year', 'date'])['AQI'].max()
januariPoGodinama
# Out:
# Year  date
# 2019  1/1/2019     152
#       1/10/2019    209
#       1/11/2019    154
#       1/12/2019    223
#       1/13/2019    344
#                   ...
# 2023  1/5/2023     249
#       1/6/2023     270
#       1/7/2023     307
#       1/8/2023     305
#       1/9/2023     115
# Name: AQI, Length: 155, dtype: int64

# %%
decembri=data.loc[data['Month']==12]
decembri
# Out:
#              date      Site          Parameter         Date (LT)  Hour  \
# 4553    12/1/2018  Sarajevo  PM2.5 - Principal    12/1/2018 0:00     0
# 4554    12/1/2018  Sarajevo  PM2.5 - Principal    12/1/2018 1:00     1
# 4555    12/1/2018  Sarajevo  PM2.5 - Principal    12/1/2018 2:00     2
# 4556    12/1/2018  Sarajevo  PM2.5 - Principal    12/1/2018 3:00     3
# 4557    12/1/2018  Sarajevo  PM2.5 - Principal    12/1/2018 4:00     4
# ...           ...       ...                ...               ...   ...
# 42328  12/31/2022  Sarajevo  PM2.5 - Principal  12/31/2022 19:00    19
# 42329  12/31/2022  Sarajevo  PM2.5 - Principal  12/31/2022 20:00    20
# 42330  12/31/2022  Sarajevo  PM2.5 - Principal  12/31/2022 21:00    21
# 42331  12/31/2022  Sarajevo  PM2.5 - Principal  12/31/2022 22:00    22
# 42332  12/31/2022  Sarajevo  PM2.5 - Principal  12/31/2022 23:00    23
#
#        NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration QC Name  \
# ...

# %%
decembriPoGodinama=decembri.groupby(['Year', 'date'])['AQI'].max()
decembriPoGodinama
# Out:
# Year  date
# 2018  12/1/2018     312
#       12/10/2018    158
#       12/11/2018    163
#       12/12/2018    175
#       12/13/2018    181
#                    ...
# 2022  12/5/2022     165
#       12/6/2022     152
#       12/7/2022     171
#       12/8/2022     165
#       12/9/2022     169
# Name: AQI, Length: 155, dtype: int64

# %%
plt.title("Maksimalna AQI vrijednost tokom decembra, januara i februara od 2018. do 2023. godine")
plt.xlabel("Godina")
plt.ylabel("AQI")

ax = plt.gca()

januariPoGodinama.plot(kind="scatter", label="Januar", ax=ax)
februariPoGodinama.plot(label="Februar", ax=ax)
decembriPoGodinama.plot(label="Decembar", ax=ax)

plt.xticks(rotation=90)


plt.legend()
plt.xlabel("Datum")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3148\498116927.py in <module>
#       5 ax = plt.gca()
#       6
# ----> 7 januariPoGodinama.plot(kind="scatter", label="Januar", ax=ax)
#       8 februariPoGodinama.plot(label="Februar", ax=ax)
#       9 decembriPoGodinama.plot(label="Decembar", ax=ax)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
# --> 919                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#     920         elif kind in self._series_kinds:
#     921             if isinstance(data, ABCDataFrame):
#
# ValueError: plot kind scatter can only be used for data frames

# %%
x1=februariPoGodinama.index[0]
februariPoGodinama[x1]
# Out:
# 161

# %%
x=februari['date']
y=februari['AQI']
plt.plot(x, y)

# %%
februariPoGodinama.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
janFebDec=data.loc[(data["Month"] == 1) | (data["Month"] == 2) | (data["Month"] == 12)]
janFebDec
# Out:
#             date      Site          Parameter        Date (LT)  Hour  \
# 4553   12/1/2018  Sarajevo  PM2.5 - Principal   12/1/2018 0:00     0
# 4554   12/1/2018  Sarajevo  PM2.5 - Principal   12/1/2018 1:00     1
# 4555   12/1/2018  Sarajevo  PM2.5 - Principal   12/1/2018 2:00     2
# 4556   12/1/2018  Sarajevo  PM2.5 - Principal   12/1/2018 3:00     3
# 4557   12/1/2018  Sarajevo  PM2.5 - Principal   12/1/2018 4:00     4
# ...          ...       ...                ...              ...   ...
# 43735  2/28/2023  Sarajevo  PM2.5 - Principal  2/28/2023 19:00    19
# 43736  2/28/2023  Sarajevo  PM2.5 - Principal  2/28/2023 20:00    20
# 43737  2/28/2023  Sarajevo  PM2.5 - Principal  2/28/2023 21:00    21
# 43738  2/28/2023  Sarajevo  PM2.5 - Principal  2/28/2023 22:00    22
# 43739  2/28/2023  Sarajevo  PM2.5 - Principal  2/28/2023 23:00    23
#
#        NowCast Conc.  AQI                    AQI Category  Raw Conc.  \
# ...

# %%
janFebDec.to_csv('C:/Pythondatasets/Jan_feb_dec_datasets_Sarajevo.csv', index=False)

# %%
mjeseciPoGodinama=janFebDec.groupby(['Year', 'date'])['AQI'].max()
mjeseciPoGodinama
# Out:
# Year  date
# 2018  12/1/2018     312
#       12/10/2018    158
#       12/11/2018    163
#       12/12/2018    175
#       12/13/2018    181
#                    ...
# 2023  2/5/2023       67
#       2/6/2023       67
#       2/7/2023      100
#       2/8/2023      154
#       2/9/2023      119
# Name: AQI, Length: 451, dtype: int64

# %%
plt.title("Maksimalna AQI vrijednost tokom decembra, januara i februara od 2018. do 2023. godine")
plt.xlabel("Godina")
plt.ylabel("AQI")

ax = plt.gca()
x=mjeseciPoGodinama.index
y1=januariPoGodinama.values.tolist()
y2=februariPoGodinama.values.tolist()
y3=decembriPoGodinama.values.tolist()


plt.plot(x, y1, label="Januar", ax=ax)

plt.xticks(rotation=90)


plt.legend()
plt.xlabel("Datum")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21920\1167944230.py in <module>
#      10
#      11
# ---> 12 plt.plot(x, y1, label="Januar", ax=ax)
#      13
#      14 plt.xticks(rotation=90)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
x=mjeseciPoGodinama.index
x
# Out:
# MultiIndex([(2018,  '12/1/2018'),
#             (2018, '12/10/2018'),
#             (2018, '12/11/2018'),
#             (2018, '12/12/2018'),
#             (2018, '12/13/2018'),
#             (2018, '12/14/2018'),
#             (2018, '12/15/2018'),
#             (2018, '12/16/2018'),
#             (2018, '12/17/2018'),
#             (2018, '12/18/2018'),
#             ...
#             (2023,  '2/26/2023'),
#             (2023,  '2/27/2023'),
#             (2023,  '2/28/2023'),
#             (2023,   '2/3/2023'),
#             (2023,   '2/4/2023'),
#             (2023,   '2/5/2023'),
#             (2023,   '2/6/2023'),
#             (2023,   '2/7/2023'),
#             (2023,   '2/8/2023'),
#             (2023,   '2/9/2023')],
#            names=['Year', 'date'], length=451)

# %%
januariPoGodinama.values.tolist()
# Out:
# [152,
#  209,
#  154,
#  223,
#  344,
#  415,
#  164,
#  294,
#  202,
#  165,
#  170,
#  193,
#  193,
#  192,
#  163,
#  188,
#  182,
#  127,
#  172,
#  289,
#  196,
#  199,
#  161,
#  221,
#  238,
#  177,
#  222,
#  229,
#  151,
#  371,
#  393,
#  335,
#  527,
#  535,
#  548,
#  327,
#  572,
#  349,
#  406,
#  400,
#  402,
#  439,
#  274,
#  188,
#  213,
#  421,
#  389,
#  357,
#  419,
#  373,
#  358,
#  223,
#  158,
#  349,
#  170,
#  158,
#  435,
#  441,
#  97,
#  272,
#  414,
#  404,
#  192,
#  166,
#  149,
#  162,
#  170,
#  244,
#  208,
#  158,
#  171,
#  165,
#  317,
#  96,
#  210,
#  214,
#  22,
#  48,
#  56,
#  102,
#  103,
#  159,
#  203,
#  182,
#  144,
#  291,
#  251,
#  167,
#  168,
#  114,
#  171,
#  184,
#  180,
#  265,
#  158,
#  113,
#  97,
#  178,
#  342,
#  358,
#  373,
#  395,
#  316,
#  195,
#  318,
#  195,
#  187,
#  202,
#  179,
#  126,
#  181,
#  366,
#  384,
#  320,
#  283,
#  215,
#  240,
#  271,
#  220,
#  40,
#  148,
#  166,
#  171,
#  164,
#  202,
#  69,
# ...

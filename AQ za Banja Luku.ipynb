# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/Pythondatasets/Banja Luka/BanjaLuka_PM2.5_2021_YTD.csv')
df2 = pd.read_csv('C:/Pythondatasets/Banja Luka/BanjaLuka_PM2.5_2022_12_MTD.csv')
df3 = pd.read_csv('C:/Pythondatasets/Banja Luka/BanjaLuka_PM2.5_2022_YTD.csv')
df4 = pd.read_csv('C:/Pythondatasets/Banja Luka/BanjaLuka_PM2.5_2023_06_MTD.csv')
df5 = pd.read_csv('C:/Pythondatasets/Banja Luka/BanjaLuka_PM2.5_2023_12_MTD.csv')
df6 = pd.read_csv('C:/Pythondatasets/Banja Luka/BanjaLuka_PM2.5_2023_YTD.csv')

# %%
df1
# Out:
#             Site          Parameter            Date (LT)  Year  Month  Day  \
# 0     Banja Luka  PM2.5 - Principal  2021-09-08 07:00 PM  2021      9    8
# 1     Banja Luka  PM2.5 - Principal  2021-09-08 08:00 PM  2021      9    8
# 2     Banja Luka  PM2.5 - Principal  2021-09-08 09:00 PM  2021      9    8
# 3     Banja Luka  PM2.5 - Principal  2021-09-08 10:00 PM  2021      9    8
# 4     Banja Luka  PM2.5 - Principal  2021-09-08 11:00 PM  2021      9    8
# ...          ...                ...                  ...   ...    ...  ...
# 2721  Banja Luka  PM2.5 - Principal  2021-12-31 08:00 PM  2021     12   31
# 2722  Banja Luka  PM2.5 - Principal  2021-12-31 09:00 PM  2021     12   31
# 2723  Banja Luka  PM2.5 - Principal  2021-12-31 10:00 PM  2021     12   31
# 2724  Banja Luka  PM2.5 - Principal  2021-12-31 11:00 PM  2021     12   31
# 2725  Banja Luka  PM2.5 - Principal  2022-01-01 12:00 AM  2022      1    1
#
# ...

# %%
all_df = [ df1, df2, df3, df4, df5, df6 ]
data = pd.concat(all_df)

# %%
data
# Out:
#             Site          Parameter            Date (LT)  Year  Month  Day  \
# 0     Banja Luka  PM2.5 - Principal  2021-09-08 07:00 PM  2021      9    8
# 1     Banja Luka  PM2.5 - Principal  2021-09-08 08:00 PM  2021      9    8
# 2     Banja Luka  PM2.5 - Principal  2021-09-08 09:00 PM  2021      9    8
# 3     Banja Luka  PM2.5 - Principal  2021-09-08 10:00 PM  2021      9    8
# 4     Banja Luka  PM2.5 - Principal  2021-09-08 11:00 PM  2021      9    8
# ...          ...                ...                  ...   ...    ...  ...
# 3402  Banja Luka  PM2.5 - Principal  2023-05-31 09:00 PM  2023      5   31
# 3403  Banja Luka  PM2.5 - Principal  2023-05-31 10:00 PM  2023      5   31
# 3404  Banja Luka  PM2.5 - Principal  2023-05-31 11:00 PM  2023      5   31
# 3405  Banja Luka  PM2.5 - Principal  2023-06-01 12:00 AM  2023      6    1
# 3406  Banja Luka  PM2.5 - Principal  2023-06-01 01:00 AM  2023      6    1
#
# ...

# %%
data = data.loc[(data["QC Name"] == 'Valid') & (data["AQI"] > 0)]

# %%
data
# Out:
#             Site          Parameter            Date (LT)  Year  Month  Day  \
# 1     Banja Luka  PM2.5 - Principal  2021-09-08 08:00 PM  2021      9    8
# 2     Banja Luka  PM2.5 - Principal  2021-09-08 09:00 PM  2021      9    8
# 3     Banja Luka  PM2.5 - Principal  2021-09-08 10:00 PM  2021      9    8
# 4     Banja Luka  PM2.5 - Principal  2021-09-08 11:00 PM  2021      9    8
# 5     Banja Luka  PM2.5 - Principal  2021-09-09 12:00 AM  2021      9    9
# ...          ...                ...                  ...   ...    ...  ...
# 3402  Banja Luka  PM2.5 - Principal  2023-05-31 09:00 PM  2023      5   31
# 3403  Banja Luka  PM2.5 - Principal  2023-05-31 10:00 PM  2023      5   31
# 3404  Banja Luka  PM2.5 - Principal  2023-05-31 11:00 PM  2023      5   31
# 3405  Banja Luka  PM2.5 - Principal  2023-06-01 12:00 AM  2023      6    1
# 3406  Banja Luka  PM2.5 - Principal  2023-06-01 01:00 AM  2023      6    1
#
# ...

# %%
data.to_csv('C:/Pythondatasets/Banja Luka/All_Valid_Datasets_Banja_Luka.csv', index=False)

# %%
data=pd.read_csv('C:/Pythondatasets/Banja Luka/All_Valid_Datasets_Banja_Luka.csv')

# %%
data
# Out:
#              Site          Parameter            Date (LT)  Year  Month  Day  \
# 0      Banja Luka  PM2.5 - Principal  2021-09-08 08:00 PM  2021      9    8
# 1      Banja Luka  PM2.5 - Principal  2021-09-08 09:00 PM  2021      9    8
# 2      Banja Luka  PM2.5 - Principal  2021-09-08 10:00 PM  2021      9    8
# 3      Banja Luka  PM2.5 - Principal  2021-09-08 11:00 PM  2021      9    8
# 4      Banja Luka  PM2.5 - Principal  2021-09-09 12:00 AM  2021      9    9
# ...           ...                ...                  ...   ...    ...  ...
# 15451  Banja Luka  PM2.5 - Principal  2023-05-31 09:00 PM  2023      5   31
# 15452  Banja Luka  PM2.5 - Principal  2023-05-31 10:00 PM  2023      5   31
# 15453  Banja Luka  PM2.5 - Principal  2023-05-31 11:00 PM  2023      5   31
# 15454  Banja Luka  PM2.5 - Principal  2023-06-01 12:00 AM  2023      6    1
# 15455  Banja Luka  PM2.5 - Principal  2023-06-01 01:00 AM  2023      6    1
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataSA = pd.read_csv('C:/Pythondatasets/All_Valid_Datasets_Sarajevo_without_duplicates.csv')
dataSA
# Out:
#            Site          Parameter            Date (LT)  Year  Month  Day  \
# 0      Sarajevo  PM2.5 - Principal  2018-05-22 17:00:00  2018      5   22
# 1      Sarajevo  PM2.5 - Principal  2018-05-22 18:00:00  2018      5   22
# 2      Sarajevo  PM2.5 - Principal  2018-05-22 19:00:00  2018      5   22
# 3      Sarajevo  PM2.5 - Principal  2018-05-22 20:00:00  2018      5   22
# 4      Sarajevo  PM2.5 - Principal  2018-05-22 21:00:00  2018      5   22
# ...         ...                ...                  ...   ...    ...  ...
# 41472  Sarajevo  PM2.5 - Principal  2023-04-30 21:00:00  2023      4   30
# 41473  Sarajevo  PM2.5 - Principal  2023-04-30 22:00:00  2023      4   30
# 41474  Sarajevo  PM2.5 - Principal  2023-04-30 23:00:00  2023      4   30
# 41475  Sarajevo  PM2.5 - Principal  2023-05-01 00:00:00  2023      5    1
# 41476  Sarajevo  PM2.5 - Principal  2023-05-01 01:00:00  2023      5    1
#
#        Hour  NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration  \
# ...

# %%
dataBL = pd.read_csv('C:/Pythondatasets/Banja Luka/All_Valid_Datasets_BanjaLuka_without_duplicates.csv')
dataBL
# Out:
#              Site          Parameter            Date (LT)  Year  Month  Day  \
# 0      Banja Luka  PM2.5 - Principal  2021-09-08 08:00 PM  2021      9    8
# 1      Banja Luka  PM2.5 - Principal  2021-09-08 09:00 PM  2021      9    8
# 2      Banja Luka  PM2.5 - Principal  2021-09-08 10:00 PM  2021      9    8
# 3      Banja Luka  PM2.5 - Principal  2021-09-08 11:00 PM  2021      9    8
# 4      Banja Luka  PM2.5 - Principal  2021-09-09 12:00 AM  2021      9    9
# ...           ...                ...                  ...   ...    ...  ...
# 14016  Banja Luka  PM2.5 - Principal  2023-05-31 09:00 PM  2023      5   31
# 14017  Banja Luka  PM2.5 - Principal  2023-05-31 10:00 PM  2023      5   31
# 14018  Banja Luka  PM2.5 - Principal  2023-05-31 11:00 PM  2023      5   31
# 14019  Banja Luka  PM2.5 - Principal  2023-06-01 12:00 AM  2023      6    1
# 14020  Banja Luka  PM2.5 - Principal  2023-06-01 01:00 AM  2023      6    1
#
# ...

# %%
df_out2018_SA = dataSA.loc[dataSA['Year']==2018]
df_out2019_SA = dataSA.loc[dataSA['Year']==2019]
df_out2020_SA = dataSA.loc[dataSA['Year']==2020]
df_out2021_SA = dataSA.loc[dataSA['Year']==2021]
df_out2022_SA = dataSA.loc[dataSA['Year']==2022]
df_out2023_SA = dataSA.loc[dataSA['Year']==2023]

# %%
AQI2018_SA=df_out2018_SA['AQI']
AQI2019_SA=df_out2019_SA['AQI']
AQI2020_SA=df_out2020_SA['AQI']
AQI2021_SA=df_out2021_SA['AQI']
AQI2022_SA=df_out2022_SA['AQI']
AQI2023_SA=df_out2023_SA['AQI']

# %%
plt.figure(figsize=(10, 6))
plt.scatter(dataSA['AQI'], dataSA['Raw Conc.'], marker='o', color='blue', alpha=0.7)
plt.xlabel("AQI")
plt.ylabel('PM2.5')
plt.title("Scatter plot of AQI and PM2.5 in Sarajevo from 2018 to 2023")
plt.grid(True)
plt.tight_layout()
plt.savefig('C:/Pythondatasets/scatter_plot_AQI.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(dataBL['AQI'], dataBL['Raw Conc.'], marker='o', color='blue', alpha=0.7)
plt.xlabel("AQI")
plt.ylabel('PM2.5')
plt.title("Scatter plot of AQI and PM2.5 in Banja Luka from 2021 to 2023")
plt.grid(True)
plt.tight_layout()
plt.savefig('C:/Pythondatasets/scatter_plot_AQI_BanjaLuka.png')
plt.show()

# %%
import numpy as np
from scipy import stats

# Example AQI data
aqi_values = dataSA['AQI']

# Calculate the Z-Scores for AQI data
z_scores = np.abs(stats.zscore(aqi_values))

# Define a threshold for identifying outliers (e.g., Z-Score > 2)
threshold = 2

# Identify outliers
outliers = [aqi_values[i] for i in range(len(aqi_values)) if z_scores[i] > threshold]

# Print the identified outliers
print("Outliers:", outliers)
# Out:
# Outliers: [214, 217, 227, 212, 217, 238, 242, 237, 226, 229, 232, 226, 218, 212, 211, 210, 219, 221, 221, 229, 242, 268, 289, 312, 311, 297, 286, 280, 278, 288, 278, 271, 254, 236, 226, 226, 228, 232, 248, 268, 294, 304, 315, 333, 340, 378, 396, 394, 364, 346, 323, 293, 279, 272, 258, 246, 241, 238, 245, 255, 261, 276, 298, 307, 323, 341, 339, 357, 376, 376, 379, 393, 428, 409, 296, 404, 410, 386, 364, 372, 366, 380, 384, 383, 379, 386, 377, 350, 316, 248, 213, 229, 223, 222, 220, 238, 233, 230, 220, 270, 295, 335, 340, 318, 311, 297, 281, 279, 333, 335, 332, 327, 319, 315, 296, 285, 276, 289, 285, 244, 220, 224, 215, 264, 278, 285, 298, 313, 306, 287, 311, 323, 299, 295, 300, 290, 271, 253, 251, 230, 217, 223, 339, 338, 438, 450, 474, 484, 462, 406, 355, 336, 343, 331, 270, 240, 213, 235, 233, 260, 286, 333, 355, 363, 336, 319, 381, 329, 385, 334, 370, 361, 328, 283, 257, 227, 212, 220, 233, 269, 289, 291, 308, 309, 339, 371, 412, 418, 427, 440, 442, 456, 460, 451, 441, 432, 424, 39
# ...

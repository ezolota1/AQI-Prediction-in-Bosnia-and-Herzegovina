# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data_sa = pd.read_csv('C:/Pythondatasets/All_Valid_Datasets_Sarajevo_sa_datumom - Copy.csv')
data_sa.columns
# Out:
# Index(['date', 'Site', 'Parameter', 'Date (LT)', 'Hour', 'NowCast Conc.',
#        'AQI', 'AQI Category', 'Raw Conc.', 'Conc. Unit', 'Duration', 'QC Name',
#        'Month', 'Year'],
#       dtype='object')

# %%
data_bl = pd.read_csv('C:/Pythondatasets/Banja Luka/All_Valid_Datasets_Banja_Luka_sa_datumom - Copy.csv')
data_bl
# Out:
#             date        Site          Parameter        Date (LT)  Hour  \
# 0       9/8/2021  Banja Luka  PM2.5 - Principal   9/8/2021 20:00    20
# 1       9/8/2021  Banja Luka  PM2.5 - Principal   9/8/2021 21:00    21
# 2       9/8/2021  Banja Luka  PM2.5 - Principal   9/8/2021 22:00    22
# 3       9/8/2021  Banja Luka  PM2.5 - Principal   9/8/2021 23:00    23
# 4       9/9/2021  Banja Luka  PM2.5 - Principal    9/9/2021 0:00     0
# ...          ...         ...                ...              ...   ...
# 15451  5/31/2023  Banja Luka  PM2.5 - Principal  5/31/2023 21:00    21
# 15452  5/31/2023  Banja Luka  PM2.5 - Principal  5/31/2023 22:00    22
# 15453  5/31/2023  Banja Luka  PM2.5 - Principal  5/31/2023 23:00    23
# 15454   6/1/2023  Banja Luka  PM2.5 - Principal    6/1/2023 0:00     0
# 15455   6/1/2023  Banja Luka  PM2.5 - Principal    6/1/2023 1:00     1
#
#        NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration QC Name  \
# ...

# %%
frames = [data_sa, data_bl]  
  
data = pd.concat(frames)  
data
# Out:
#             date        Site          Parameter        Date (LT)  Hour  \
# 0      5/22/2018    Sarajevo  PM2.5 - Principal  5/22/2018 17:00    17
# 1      5/22/2018    Sarajevo  PM2.5 - Principal  5/22/2018 18:00    18
# 2      5/22/2018    Sarajevo  PM2.5 - Principal  5/22/2018 19:00    19
# 3      5/22/2018    Sarajevo  PM2.5 - Principal  5/22/2018 20:00    20
# 4      5/22/2018    Sarajevo  PM2.5 - Principal  5/22/2018 21:00    21
# ...          ...         ...                ...              ...   ...
# 15451  5/31/2023  Banja Luka  PM2.5 - Principal  5/31/2023 21:00    21
# 15452  5/31/2023  Banja Luka  PM2.5 - Principal  5/31/2023 22:00    22
# 15453  5/31/2023  Banja Luka  PM2.5 - Principal  5/31/2023 23:00    23
# 15454   6/1/2023  Banja Luka  PM2.5 - Principal    6/1/2023 0:00     0
# 15455   6/1/2023  Banja Luka  PM2.5 - Principal    6/1/2023 1:00     1
#
#        NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration QC Name  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
X=data[['Year', 'Month', 'Hour']]
Y=data['AQI Category']

X_train, X_test, Y_train, Y_test=train_test_split(X, Y, test_size=0.33, random_state=70)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)

# Logistic Regression

log_reg=LogisticRegression().fit(X_train, Y_train)

train_pred=log_reg.predict(X_train)
print("Model accuracy on train is: ", accuracy_score(Y_train, train_pred))

test_pred=log_reg.predict(X_test)
print("Model accuracy on test is: ", accuracy_score(Y_test, test_pred))
print("-"*50)

print("KappaScore is ", metrics.cohen_kappa_score(Y_test, test_pred))
# Out:
# (40628, 3) (20011, 3) (40628,) (20011,)
# Model accuracy on train is:  0.42999901545732006
# Model accuracy on test is:  0.43381140372794963
# --------------------------------------------------
# KappaScore is  0.0
